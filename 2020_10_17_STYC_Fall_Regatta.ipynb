# %% [markdown]
# # Race Review
#
# This is a general page that will display info about a race day.

# %%
# These are libraries written for RaceAnalysis
from global_variables import G
from nbutils import display_markdown, display
import race_logs
import metadata as m
import process as p
import analysis as a
import chart as ch
import utils
import numpy as np

import nbutils

# Initialize for Seattle.
G.init_seattle(logging_level="INFO")

# %%
date = '2020-10-17'
df, race = race_logs.read_date(date)
chart = ch.trim_track(df)
# Out:
# 2020-10-19 19:24:18,148|INFO|read_metadata| Read 98 records.
# 2020-10-19 19:24:18,149|INFO|read_logs| Reading file 2020-10-17_09:03.pd.gz
# 2020-10-19 19:24:19,611|INFO|read_log_file| Session from 2020-10-17 16:03:20.070000, 265745 rows, 7.381388888888889 hours.
# 2020-10-19 19:24:21,263|INFO|read_logs| Found 265740 records before trim.
# 2020-10-19 19:24:21,305|INFO|read_logs| Trimming to 0 -1
# <img src="data:image/png;base64,..." width="600">

# %%
if chart.is_trimmed:
    display("Updating Trim!")
    race_logs.trim_race(race, chart.begin, chart.end)

# %%
(chart.begin, chart.end)
# Out:
# (45474, 57100)

# %%
sdf = df.iloc[45474:57100]

# %%
m.display_race_metadata(race)
# Out:
# # Styc fall regatta: 2020-10-17
# ## Description
# Three races. NERN, NBMN, NBWMN.  Wind was nice but shut off toward the end.  Luckily we made it around. Some boats came in an hour later.
# ## Conditions
# 43 boats out there.  Nice wind. No rain but cloudy
# ## Performance
# Pretty well
# ## Learnings
# Tight situations might need to be ready for taxican.  Sheet on hard and alert crew.  Adjust halyards for light wind going down and bring back up
# ## Extras
# - **file**: 2020-10-17_09:03.pd.gz
# - **date**: 2020-10-17
# - **title**: Styc fall regatta
# - **begin**: 0
# - **end**: -1
# - **source**: gsheet
# - **purpose**: race
# - **crew**: ['Sara', 'Paul']
# - **warnings**: Jib needs a bit more tape
# - **wave**: flat
# - **wind**: [4, 10]
# - **port_pointing**: 31-33
# - **stbd_pointing**: 31-33
# - **settings**: Light wind.  Loose outhaul. Brian loosen main halyard
# - **shroud_name**: Light wind
# - **other**: We passed One Life to windward very successfully.
# - **additional_crew**: LA,  Brian, April.
# - **timestamp**: 2020-10-18 01:34:25
# - **fluid_comments**: No water left in the tank
# - **fluids**: Empty Bilge?
# - **Shroud tensions (UP-MID-LOW: sep with hyphens: 29-10-0). Pos low is tension, neg low is circle size in cm).**: 29-10-0

# %%
variation = np.mean(sdf.variation)

# %%
sdf
# Out:
#          rhdg  raws     rawa  rudder  turn_rate  rsog  latitude  longitude  \
# 45484 267.200 3.370 -103.000   5.000      0.483 2.190    47.685   -122.411
# 45485 267.200 3.370 -103.000   5.000      0.483 2.180    47.685   -122.411
# 45486 267.300 3.370 -102.000   5.000      0.423 2.170    47.685   -122.411
# 45487 267.400 3.370  -97.000   5.000      0.659 2.170    47.685   -122.411
# 45488 267.400 3.370  -97.000   5.000      0.780 2.130    47.685   -122.411
# ...       ...   ...      ...     ...        ...   ...       ...        ...
# 57105  13.400 2.880  119.800   1.200      1.318 3.010    47.693   -122.412
# 57106  13.600 2.880  114.400   0.800      1.434 3.010    47.693   -122.412
# 57107  13.700 2.880  114.400   0.400      1.318 3.010    47.693   -122.412
# 57108  13.900 2.880  109.100   0.100      1.258 3.020    47.693   -122.412
# 57109  14.000 2.880  105.100  -0.100      0.961 3.020    47.693   -122.412
#
#        row_seconds  zeus_cog  ...   tws      twa    stwd  stws     stwa   spd  \
# 45484     4548.400   284.200  ... 4.840 -121.420 167.107 4.778 -115.255 1.950
# 45485     4548.500   284.200  ... 4.839 -121.441 167.103 4.778 -115.259 1.950
# 45486     4548.600   285.400  ... 4.839 -121.560 167.099 4.778 -115.363 1.950
# 45487     4548.700   285.400  ... 4.838 -121.670 167.096 4.778 -115.466 1.950
# 45488     4548.800   285.400  ... 4.837 -121.679 167.093 4.778 -115.469 1.950
# ...            ...       ...  ...   ...      ...     ...   ...      ...   ...
# 57105     5710.500    28.100  ... 5.176  149.112 170.508 5.159  141.946 2.561
# 57106     5710.600    26.300  ... 5.176  148.915 170.510 5.159  141.749 2.560
# 57107     5710.700    26.300  ... 5.175  148.817 170.513 5.159  141.651 2.560
# 57108     5710.800    26.900  ... 5.175  148.614 170.514 5.158  141.453 2.560
# 57109     5710.900    26.900  ... 5.174  148.507 170.515 5.158  141.354 2.560
#
#         sog     hdg     cog                           row_times
# 45484 2.184 267.047 280.101 2020-10-17 10:19:07.777610368-07:00
# 45485 2.183 267.078 280.081 2020-10-17 10:19:07.877635901-07:00
# 45486 2.181 267.122 280.043 2020-10-17 10:19:07.977661434-07:00
# 45487 2.178 267.178 280.008 2020-10-17 10:19:08.077686967-07:00
# 45488 2.169 267.222 279.948 2020-10-17 10:19:08.177709947-07:00
# ...     ...     ...     ...                                 ...
# 57105 3.016  13.076  23.332 2020-10-17 10:38:29.878935895-07:00
# 57106 3.015  13.181  23.519 2020-10-17 10:38:29.979055994-07:00
# 57107 3.014  13.284  23.677 2020-10-17 10:38:30.079176092-07:00
# 57108 3.015  13.408  23.679 2020-10-17 10:38:30.179284181-07:00
# 57109 3.016  13.526  23.722 2020-10-17 10:38:30.279392269-07:00
#
# [11626 rows x 39 columns]

# %%
cc = ch.chart_and_plot(sdf, None, (sdf.stwd, sdf.hdg, sdf.hdg+variation))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sdf.tws
# Out:
# 45484   4.840
# 45485   4.839
# 45486   4.839
# 45487   4.838
# 45488   4.837
#          ...
# 57105   5.176
# 57106   5.176
# 57107   5.175
# 57108   5.175
# 57109   5.174
# Name: tws, Length: 11626, dtype: float64

# %%
cc = ch.chart_and_plot(sdf, sdf.row_times, (sdf.twd, sdf.hdg))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sdf.columns
# Out:
# Index(['rhdg', 'raws', 'rawa', 'rudder', 'turn_rate', 'rsog', 'latitude',
#        'longitude', 'row_seconds', 'zeus_cog', 'zeus_sog', 'variation', 'rspd',
#        'depth', 'altitude', 'geoidal_separation', 'zg100_pitch', 'zg100_roll',
#        'zeus_altitude', 'zeus_gnss_type', 'rcog', 'timestamp', 'awa', 'aws',
#        'cawa', 'caws', 'scawa', 'scaws', 'twd', 'tws', 'twa', 'stwd', 'stws',
#        'stwa', 'spd', 'sog', 'hdg', 'cog', 'row_times'],
#       dtype='object')

# %%
sdf.row_times
# Out:
# 45484   2020-10-17 10:19:07.777610368-07:00
# 45485   2020-10-17 10:19:07.877635901-07:00
# 45486   2020-10-17 10:19:07.977661434-07:00
# 45487   2020-10-17 10:19:08.077686967-07:00
# 45488   2020-10-17 10:19:08.177709947-07:00
#                         ...
# 57105   2020-10-17 10:38:29.878935895-07:00
# 57106   2020-10-17 10:38:29.979055994-07:00
# 57107   2020-10-17 10:38:30.079176092-07:00
# 57108   2020-10-17 10:38:30.179284181-07:00
# 57109   2020-10-17 10:38:30.279392269-07:00
# Name: row_times, Length: 11626, dtype: datetime64[ns, US/Pacific]
