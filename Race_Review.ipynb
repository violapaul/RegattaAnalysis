# %% [markdown]
# # Race Review
#
# This is a general page that will display info about a race day.

# %%
# These are libraries written for RaceAnalysis
from global_variables import G
from nbutils import display_markdown, display
import race_logs
import metadata as m
import process as p
import analysis as a
import chart as ch
import utils
import numpy as np

import nbutils

# Initialize for Seattle.
G.init_seattle(logging_level="INFO")

# %%
date = '2021-03-27'
df, race = race_logs.read_date(date)
chart = ch.trim_track(df)
# Out:
# 2021-04-04 11:00:45,710|INFO|read_metadata| Read 118 records.
# 2021-04-04 11:00:45,710|INFO|read_logs| Reading file 2021-03-27_08:58.pd.gz
# 2021-04-04 11:00:46,793|INFO|read_log_file| Session from 2021-03-27 15:58:40.020000, 241637 rows, 6.711666666666667 hours.
# 2021-04-04 11:00:47,642|INFO|read_logs| Found 241637 records before trim.
# 2021-04-04 11:00:47,678|INFO|read_logs| Trimming to 0 -1
# <img src="data:image/png;base64,..." width="600">

# %%
if chart.is_trimmed:
    display("Updating Trim!")
    race_logs.trim_race(race, chart.begin, chart.end)
# Out:
# 'Updating Trim!'
# 2021-04-04 11:01:12,974|INFO|read_metadata| Read 118 records.
# 2021-04-04 11:01:12,975|INFO|save_metadata| Writing 111 records.

# %%
(chart.begin, chart.end)
# Out:
# (45377, 226603)

# %%
sdf = df.iloc[45474:57100]

# %%
m.display_race_metadata(race)

# %%
variation = np.mean(sdf.variation)

# %%
sdf

# %%
cc = ch.chart_and_plot(sdf, None, (sdf.stwd, sdf.hdg, sdf.hdg+variation))

# %%
sdf.tws

# %%
cc = ch.chart_and_plot(sdf, sdf.row_times, (sdf.twd, sdf.hdg))

# %%
sdf.columns

# %%
sdf.row_times
