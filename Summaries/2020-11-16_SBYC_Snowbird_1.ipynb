# %% [markdown]
# # SBYC Snowbird 1, November 16th, 2020

# %% [markdown]
# West Point Wind
#
#
#
# Golden Gardens Wind

# %%
# Load some libraries
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})

import numpy as np

# These are libraries written for RaceAnalysis
from global_variables import G
import race_logs
import process as p
import analysis as a
import chart as c

G.init_seattle()

# %%
import importlib
importlib.reload(c)
# Out:
# <module 'chart' from '/Users/viola/GDrive/Sailboat/Code/Python/sailing/chart.py'>

# %%
dfs, races, big_df = race_logs.read_dates(["2019-11-16"])
# dfs, races, big_df = race_logs.read_dates(["2019-11-16"])
df = dfs[0]
races
# Out:
# Session from 2019-11-16 18:09:15.020000, 128865 rows, 3.5797222222222222 hours.
# [file              2019-11-16_10:09.pd.gz
#  race                         Snowbird #1
#  begin                              41076
#  end                               111668
#  datetime       2019-11-16 10:09:00-08:00
#  description                 Snowbird #1.
#  Name: 22, dtype: object]

# %%
chart = c.plot_chart(df)
c.draw_track(df, chart, color='green')
# Out:
# 2020-04-30 13:15:02,938|INFO|run_system_command| Running command: rm /tmp/chart.tif
# 2020-04-30 13:15:02,944|INFO|run_system_command| Command finished in 0.005 seconds.
# 2020-04-30 13:15:02,945|INFO|run_system_command| Running command: gdalwarp  -te -122.4456422 47.6555354 -122.3695711 47.7559130 -t_srs ' +proj=tmerc +lat_0=47.6873070 +lon_0=-122.4386440 +k_0=0.9996 +datum=WGS84 +units=m +no_defs ' -te_srs EPSG:4326 -r bilinear -ts 0 2000 Data/maps/seattle_base_map.tif /tmp/chart.tif
# 2020-04-30 13:15:03,382|INFO|run_system_command| Command finished in 0.437 seconds.
# <img src="data:image/png;base64,..." width="640">

# %%
chart.image.shape
# Out:
# (2000, 1022, 3)

# %%
df.latitude.mean(), df.longitude.mean()
# Out:
# (47.70659473250747, -122.41029184218408)

# %%
plt.figure()
wdf.awa.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
race_slice = slice(example.begin, example.end)
race_slice = slice(begin, end)
wdf = df.loc[race_slice]
print(wdf.row_times.min(), wdf.row_times.max())
ch = c.show_boat_arrows(df, race_slice, dt_seconds=10, skip=1)
# Out:
# 2020-02-08 11:41:21.869960489-08:00 2020-02-08 11:50:59.242969461-08:00
# <img src="data:image/png;base64,..." width="320">

# %%
wdf.row_times
# Out:
# 46510   2020-02-08 11:41:21.869960489-08:00
# 46511   2020-02-08 11:41:21.974937400-08:00
# 46512   2020-02-08 11:41:22.079914310-08:00
# 46513   2020-02-08 11:41:22.184891221-08:00
# 46514   2020-02-08 11:41:22.289868132-08:00
#                         ...
# 52006   2020-02-08 11:50:58.823061818-08:00
# 52007   2020-02-08 11:50:58.928038729-08:00
# 52008   2020-02-08 11:50:59.033015640-08:00
# 52009   2020-02-08 11:50:59.137992550-08:00
# 52010   2020-02-08 11:50:59.242969461-08:00
# Name: row_times, Length: 5501, dtype: datetime64[ns, US/Pacific]

# %%
import tides

plt.figure()
ttt = tides.tides_at(odf.row_times)
plt.plot(odf.row_times, ttt)

# %%
df.variation

# %%
wdf.twd

# %%
c.quick_plot(df.row_times, (df.twd, 20*df.tws))

# %%
wdf.row_times
